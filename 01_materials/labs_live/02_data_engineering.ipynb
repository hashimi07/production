# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account.
#
# Extract all files into the directory: `./05_src/data/prices_csv/`
#
# Your folder structure should include the following paths:
#
# + `05_src/data/prices_csv/etfs`
# + `05_src/data/prices_csv/stocks`

# %%
import os
import pandas as pd

# These are your actual csv folders (edit if your path is different!)
csv_folders = [
    r"C:\Users\hashi\OneDrive\Desktop\Production\production\05_src\data\prices_csv\etfs",
    r"C:\Users\hashi\OneDrive\Desktop\Production\production\05_src\data\prices_csv\stocks"
]

# This is your output folder for parquet files:
parquet_folder = r"C:\Users\hashi\OneDrive\Desktop\Production\production\05_src\data\prices"

# Make sure the output folder exists
os.makedirs(parquet_folder, exist_ok=True)

# Loop through both csv folders
for csv_folder in csv_folders:
    for csv_file in os.listdir(csv_folder):
        if csv_file.endswith('.csv'):
            csv_path = os.path.join(csv_folder, csv_file)
            df = pd.read_csv(csv_path)
            parquet_path = os.path.join(parquet_folder, csv_file.replace('.csv', '.parquet'))
            df.to_parquet(parquet_path)
            print(f"Converted {csv_file} to parquet.")
# Out:
# Converted AAAU.csv to parquet.
# Converted AADR.csv to parquet.
# Converted AAXJ.csv to parquet.
# Converted ABEQ.csv to parquet.
# Converted ACES.csv to parquet.
# Converted ACIO.csv to parquet.
# Converted ACSG.csv to parquet.
# Converted ACSI.csv to parquet.
# Converted ACT.csv to parquet.
# Converted ACWF.csv to parquet.
# Converted ACWI.csv to parquet.
# Converted ACWV.csv to parquet.
# Converted ACWX.csv to parquet.
# Converted ADME.csv to parquet.
# Converted ADRE.csv to parquet.
# Converted AESR.csv to parquet.
# Converted AFIF.csv to parquet.
# Converted AFK.csv to parquet.
# Converted AFLG.csv to parquet.
# Converted AFMC.csv to parquet.
# Converted AFSM.csv to parquet.
# Converted AFTY.csv to parquet.
# Converted AGG.csv to parquet.
# Converted AGGP.csv to parquet.
# Converted AGGY.csv to parquet.
# Converted AGND.csv to parquet.
# Converted AGQ.csv to parquet.
# Converted AGT.csv to parquet.
# Converted AGZ.csv to parquet.
# Converted AGZD.csv to parquet.
# Converted AIA.csv to parquet.
# Converted AIEQ.csv to parquet.
# Converted AIIQ.csv to parquet.
# Converted AIQ.csv to parquet.
# Converted AIRR.csv to parquet.
# Converted ALFA.csv to parquet.
# Converted ALTS.csv to parquet.
# Converted ALTY.csv to parquet.
# Converted AMCA.csv to parquet.
# Converted AMLP.csv to parquet.
# Converted AMOM.csv to parquet.
# Converted AMZA.csv to parquet.
# Converted ANGL.csv to parquet.
# Converted AOA.csv to parquet.
# Converted AOK.csv to parquet.
# Converted AOM.csv to parquet.
# Converted AOR.csv to parquet.
# Converted ARCM.csv to parquet.
# Converted ARGT.csv to parquet.
# Converted ARKF.csv to parquet.
# Converted ARKG.csv to parquet.
# Converted ARKK.csv to parquet.
# Converted ARKQ.csv to parquet.
# Converted ARKW.csv to parquet.
# Converted ARMR.csv to parquet.
# Converted ASEA.csv to parquet.
# Converted ASET.csv to parquet.
# Converted ASHR.csv to parquet.
# Converted ASHS.csv to parquet.
# Converted ASHX.csv to parquet.
# Converted AUSF.csv to parquet.
# Converted AVDE.csv to parquet.
# Converted AVDV.csv to parquet.
# Converted AVEM.csv to parquet.
# Converted AVUS.csv to parquet.
# Converted AVUV.csv to parquet.
# Converted AWAY.csv to parquet.
# Converted AWTM.csv to parquet.
# Converted AXJL.csv to parquet.
# Converted BAB.csv to parquet.
# Converted BAPR.csv to parquet.
# Converted BATT.csv to parquet.
# Converted BAUG.csv to parquet.
# Converted BBAX.csv to parquet.
# Converted BBC.csv to parquet.
# Converted BBCA.csv to parquet.
# Converted BBEU.csv to parquet.
# Converted BBH.csv to parquet.
# Converted BBIN.csv to parquet.
# Converted BBJP.csv to parquet.
# Converted BBP.csv to parquet.
# Converted BBRE.csv to parquet.
# Converted BBSA.csv to parquet.
# Converted BBUS.csv to parquet.
# Converted BCD.csv to parquet.
# Converted BCI.csv to parquet.
# Converted BDCY.csv to parquet.
# Converted BDEC.csv to parquet.
# Converted BDRY.csv to parquet.
# Converted BFEB.csv to parquet.
# Converted BFIT.csv to parquet.
# Converted BFOR.csv to parquet.
# Converted BGRN.csv to parquet.
# Converted BIB.csv to parquet.
# Converted BIBL.csv to parquet.
# Converted BICK.csv to parquet.
# Converted BIL.csv to parquet.
# Converted BIS.csv to parquet.
# Converted BIV.csv to parquet.
# Converted BIZD.csv to parquet.
# Converted BJAN.csv to parquet.
# Converted BJK.csv to parquet.
# Converted BJUL.csv to parquet.
# Converted BJUN.csv to parquet.
# Converted BKF.csv to parquet.
# Converted BKLN.csv to parquet.
# Converted BLCN.csv to parquet.
# Converted BLES.csv to parquet.
# Converted BLHY.csv to parquet.
# Converted BLOK.csv to parquet.
# Converted BLV.csv to parquet.
# Converted BMAR.csv to parquet.
# Converted BND.csv to parquet.
# Converted BNDC.csv to parquet.
# Converted BNDW.csv to parquet.
# Converted BNDX.csv to parquet.
# Converted BNO.csv to parquet.
# Converted BNOV.csv to parquet.
# Converted BOCT.csv to parquet.
# Converted BOIL.csv to parquet.
# Converted BOND.csv to parquet.
# Converted BOSS.csv to parquet.
# Converted BOTZ.csv to parquet.
# Converted BOUT.csv to parquet.
# Converted BRF.csv to parquet.
# Converted BRZU.csv to parquet.
# Converted BSAE.csv to parquet.
# Converted BSBE.csv to parquet.
# Converted BSCE.csv to parquet.
# Converted BSCK.csv to parquet.
# Converted BSCL.csv to parquet.
# Converted BSCM.csv to parquet.
# Converted BSCN.csv to parquet.
# Converted BSCO.csv to parquet.
# Converted BSCP.csv to parquet.
# Converted BSCQ.csv to parquet.
# Converted BSCR.csv to parquet.
# Converted BSCS.csv to parquet.
# Converted BSCT.csv to parquet.
# Converted BSDE.csv to parquet.
# Converted BSEP.csv to parquet.
# Converted BSJK.csv to parquet.
# Converted BSJL.csv to parquet.
# Converted BSJM.csv to parquet.
# Converted BSJN.csv to parquet.
# Converted BSJO.csv to parquet.
# Converted BSJP.csv to parquet.
# Converted BSJQ.csv to parquet.
# Converted BSJR.csv to parquet.
# Converted BSML.csv to parquet.
# Converted BSMM.csv to parquet.
# Converted BSMN.csv to parquet.
# Converted BSMO.csv to parquet.
# Converted BSMP.csv to parquet.
# Converted BSMQ.csv to parquet.
# Converted BSMR.csv to parquet.
# Converted BSMS.csv to parquet.
# Converted BSMT.csv to parquet.
# Converted BSV.csv to parquet.
# Converted BTAL.csv to parquet.
# Converted BTEC.csv to parquet.
# Converted BTYS.csv to parquet.
# Converted BUG.csv to parquet.
# Converted BUL.csv to parquet.
# Converted BUY.csv to parquet.
# Converted BUYN.csv to parquet.
# Converted BUYZ.csv to parquet.
# Converted BVAL.csv to parquet.
# Converted BWX.csv to parquet.
# Converted BWZ.csv to parquet.
# Converted BYLD.csv to parquet.
# Converted BZQ.csv to parquet.
# Converted CACG.csv to parquet.
# Converted CALF.csv to parquet.
# Converted CANE.csv to parquet.
# Converted CARZ.csv to parquet.
# Converted CATH.csv to parquet.
# Converted CBON.csv to parquet.
# Converted CCOR.csv to parquet.
# Converted CDC.csv to parquet.
# Converted CDL.csv to parquet.
# Converted CEF.csv to parquet.
# Converted CEFS.csv to parquet.
# Converted CEMB.csv to parquet.
# Converted CEW.csv to parquet.
# Converted CEY.csv to parquet.
# Converted CEZ.csv to parquet.
# Converted CFA.csv to parquet.
# Converted CFO.csv to parquet.
# Converted CGW.csv to parquet.
# Converted CHAD.csv to parquet.
# Converted CHAU.csv to parquet.
# Converted CHEP.csv to parquet.
# Converted CHGX.csv to parquet.
# Converted CHIC.csv to parquet.
# Converted CHIE.csv to parquet.
# Converted CHIH.csv to parquet.
# Converted CHII.csv to parquet.
# Converted CHIK.csv to parquet.
# Converted CHIL.csv to parquet.
# Converted CHIM.csv to parquet.
# Converted CHIQ.csv to parquet.
# Converted CHIR.csv to parquet.
# Converted CHIS.csv to parquet.
# Converted CHIU.csv to parquet.
# Converted CHIX.csv to parquet.
# Converted CHNA.csv to parquet.
# Converted CIBR.csv to parquet.
# Converted CID.csv to parquet.
# Converted CIL.csv to parquet.
# Converted CIZ.csv to parquet.
# Converted CLIX.csv to parquet.
# Converted CLOU.csv to parquet.
# Converted CLRG.csv to parquet.
# Converted CLTL.csv to parquet.
# Converted CMBS.csv to parquet.
# Converted CMDY.csv to parquet.
# Converted CMF.csv to parquet.
# Converted CN.csv to parquet.
# Converted CNBS.csv to parquet.
# Converted CNCR.csv to parquet.
# Converted CNRG.csv to parquet.
# Converted CNXT.csv to parquet.
# Converted CNYA.csv to parquet.
# Converted COM.csv to parquet.
# Converted COMB.csv to parquet.
# Converted COMT.csv to parquet.
# Converted COPX.csv to parquet.
# Converted CORN.csv to parquet.
# Converted CORP.csv to parquet.
# Converted COWZ.csv to parquet.
# Converted CPER.csv to parquet.
# Converted CPI.csv to parquet.
# Converted CQQQ.csv to parquet.
# Converted CRAK.csv to parquet.
# Converted CRBN.csv to parquet.
# Converted CROP.csv to parquet.
# Converted CSA.csv to parquet.
# Converted CSB.csv to parquet.
# Converted CSD.csv to parquet.
# Converted CSF.csv to parquet.
# Converted CSM.csv to parquet.
# Converted CSML.csv to parquet.
# Converted CURE.csv to parquet.
# Converted CUT.csv to parquet.
# Converted CVY.csv to parquet.
# Converted CWB.csv to parquet.
# Converted CWEB.csv to parquet.
# Converted CWI.csv to parquet.
# Converted CWS.csv to parquet.
# Converted CXSE.csv to parquet.
# Converted CYB.csv to parquet.
# Converted CZA.csv to parquet.
# Converted DALI.csv to parquet.
# Converted DALT.csv to parquet.
# Converted DAUG.csv to parquet.
# Converted DAX.csv to parquet.
# Converted DBA.csv to parquet.
# Converted DBAW.csv to parquet.
# Converted DBB.csv to parquet.
# Converted DBC.csv to parquet.
# Converted DBE.csv to parquet.
# Converted DBEF.csv to parquet.
# Converted DBEH.csv to parquet.
# Converted DBEM.csv to parquet.
# Converted DBEU.csv to parquet.
# Converted DBEZ.csv to parquet.
# Converted DBGR.csv to parquet.
# Converted DBJP.csv to parquet.
# Converted DBLV.csv to parquet.
# Converted DBMF.csv to parquet.
# Converted DBO.csv to parquet.
# Converted DBP.csv to parquet.
# Converted DBS.csv to parquet.
# Converted DBV.csv to parquet.
# Converted DDG.csv to parquet.
# Converted DDIV.csv to parquet.
# Converted DDLS.csv to parquet.
# Converted DDM.csv to parquet.
# Converted DDWM.csv to parquet.
# Converted DEEF.csv to parquet.
# Converted DEF.csv to parquet.
# Converted DEFA.csv to parquet.
# Converted DEM.csv to parquet.
# Converted DES.csv to parquet.
# Converted DEUS.csv to parquet.
# Converted DEW.csv to parquet.
# Converted DFE.csv to parquet.
# Converted DFEB.csv to parquet.
# Converted DFEN.csv to parquet.
# Converted DFJ.csv to parquet.
# Converted DFND.csv to parquet.
# Converted DFNL.csv to parquet.
# Converted DGL.csv to parquet.
# Converted DGRE.csv to parquet.
# Converted DGRO.csv to parquet.
# Converted DGRS.csv to parquet.
# Converted DGRW.csv to parquet.
# Converted DGS.csv to parquet.
# Converted DGT.csv to parquet.
# Converted DHS.csv to parquet.
# Converted DIA.csv to parquet.
# Converted DIAL.csv to parquet.
# Converted DIET.csv to parquet.
# Converted DIG.csv to parquet.
# Converted DIM.csv to parquet.
# Converted DINT.csv to parquet.
# Converted DIV.csv to parquet.
# Converted DIVA.csv to parquet.
# Converted DIVB.csv to parquet.
# Converted DIVO.csv to parquet.
# Converted DIVY.csv to parquet.
# Converted DJCB.csv to parquet.
# Converted DJD.csv to parquet.
# Converted DLBR.csv to parquet.
# Converted DLN.csv to parquet.
# Converted DLS.csv to parquet.
# Converted DMDV.csv to parquet.
# Converted DMRE.csv to parquet.
# Converted DMRI.csv to parquet.
# Converted DMRL.csv to parquet.
# Converted DMRM.csv to parquet.
# Converted DMRS.csv to parquet.
# Converted DNL.csv to parquet.
# Converted DNOV.csv to parquet.
# Converted DOG.csv to parquet.
# Converted DOGS.csv to parquet.
# Converted DOL.csv to parquet.
# Converted DON.csv to parquet.
# Converted DOO.csv to parquet.
# Converted DPST.csv to parquet.
# Converted DRIP.csv to parquet.
# Converted DRIV.csv to parquet.
# Converted DRN.csv to parquet.
# Converted DRSK.csv to parquet.
# Converted DRV.csv to parquet.
# Converted DRW.csv to parquet.
# Converted DSI.csv to parquet.
# Converted DSTL.csv to parquet.
# Converted DTD.csv to parquet.
# Converted DTEC.csv to parquet.
# Converted DTH.csv to parquet.
# Converted DTN.csv to parquet.
# Converted DUG.csv to parquet.
# Converted DURA.csv to parquet.
# Converted DUSA.csv to parquet.
# Converted DUSL.csv to parquet.
# Converted DUST.csv to parquet.
# Converted DVLU.csv to parquet.
# Converted DVOL.csv to parquet.
# Converted DVOP.csv to parquet.
# Converted DVP.csv to parquet.
# Converted DVY.csv to parquet.
# Converted DVYA.csv to parquet.
# Converted DVYE.csv to parquet.
# Converted DWAS.csv to parquet.
# Converted DWAT.csv to parquet.
# Converted DWAW.csv to parquet.
# Converted DWCR.csv to parquet.
# Converted DWEQ.csv to parquet.
# Converted DWFI.csv to parquet.
# Converted DWLD.csv to parquet.
# Converted DWM.csv to parquet.
# Converted DWMC.csv to parquet.
# Converted DWMF.csv to parquet.
# Converted DWPP.csv to parquet.
# Converted DWSH.csv to parquet.
# Converted DWT.csv to parquet.
# Converted DWUS.csv to parquet.
# Converted DWX.csv to parquet.
# Converted DXD.csv to parquet.
# Converted DXGE.csv to parquet.
# Converted DXJ.csv to parquet.
# Converted DXJS.csv to parquet.
# Converted DYLS.csv to parquet.
# Converted DYNF.csv to parquet.
# Converted DZK.csv to parquet.
# Converted EAGG.csv to parquet.
# Converted EASG.csv to parquet.
# Converted EASI.csv to parquet.
# Converted EBIZ.csv to parquet.
# Converted EBND.csv to parquet.
# Converted ECH.csv to parquet.
# Converted ECLN.csv to parquet.
# Converted ECNS.csv to parquet.
# Converted ECON.csv to parquet.
# Converted ECOW.csv to parquet.
# Converted ECOZ.csv to parquet.
# Converted EDC.csv to parquet.
# Converted EDEN.csv to parquet.
# Converted EDIV.csv to parquet.
# Converted EDOG.csv to parquet.
# Converted EDOW.csv to parquet.
# Converted EDV.csv to parquet.
# Converted EDZ.csv to parquet.
# Converted EELV.csv to parquet.
# Converted EEM.csv to parquet.
# Converted EEMA.csv to parquet.
# Converted EEMD.csv to parquet.
# Converted EEMO.csv to parquet.
# Converted EEMS.csv to parquet.
# Converted EEMV.csv to parquet.
# Converted EEMX.csv to parquet.
# Converted EES.csv to parquet.
# Converted EET.csv to parquet.
# Converted EEV.csv to parquet.
# Converted EFA.csv to parquet.
# Converted EFAD.csv to parquet.
# Converted EFAS.csv to parquet.
# Converted EFAV.csv to parquet.
# Converted EFAX.csv to parquet.
# Converted EFG.csv to parquet.
# Converted EFNL.csv to parquet.
# Converted EFO.csv to parquet.
# Converted EFU.csv to parquet.
# Converted EFV.csv to parquet.
# Converted EFZ.csv to parquet.
# Converted EGPT.csv to parquet.
# Converted EIDO.csv to parquet.
# Converted EINC.csv to parquet.
# Converted EIRL.csv to parquet.
# Converted EIS.csv to parquet.
# Converted EJAN.csv to parquet.
# Converted EJUL.csv to parquet.
# Converted EKAR.csv to parquet.
# Converted ELD.csv to parquet.
# Converted EMAG.csv to parquet.
# Converted EMB.csv to parquet.
# Converted EMBH.csv to parquet.
# Converted EMCB.csv to parquet.
# Converted EMCG.csv to parquet.
# Converted EMDV.csv to parquet.
# Converted EMFM.csv to parquet.
# Converted EMGF.csv to parquet.
# Converted EMHY.csv to parquet.
# Converted EMIF.csv to parquet.
# Converted EMIH.csv to parquet.
# Converted EMLC.csv to parquet.
# Converted EMLP.csv to parquet.
# Converted EMMF.csv to parquet.
# Converted EMNT.csv to parquet.
# Converted EMQQ.csv to parquet.
# Converted EMSG.csv to parquet.
# Converted EMSH.csv to parquet.
# Converted EMTL.csv to parquet.
# Converted EMTY.csv to parquet.
# Converted EMXC.csv to parquet.
# Converted ENFR.csv to parquet.
# Converted ENOR.csv to parquet.
# Converted ENTR.csv to parquet.
# Converted ENZL.csv to parquet.
# Converted EPHE.csv to parquet.
# Converted EPI.csv to parquet.
# Converted EPOL.csv to parquet.
# Converted EPP.csv to parquet.
# Converted EPRF.csv to parquet.
# Converted EPS.csv to parquet.
# Converted EPU.csv to parquet.
# Converted EPV.csv to parquet.
# Converted EQAL.csv to parquet.
# Converted EQL.csv to parquet.
# Converted EQRR.csv to parquet.
# Converted EQWL.csv to parquet.
# Converted ERM.csv to parquet.
# Converted ERSX.csv to parquet.
# Converted ERUS.csv to parquet.
# Converted ERX.csv to parquet.
# Converted ERY.csv to parquet.
# Converted ESG.csv to parquet.
# Converted ESGD.csv to parquet.
# Converted ESGE.csv to parquet.
# Converted ESGG.csv to parquet.
# Converted ESGN.csv to parquet.
# Converted ESGS.csv to parquet.
# Converted ESGU.csv to parquet.
# Converted ESGV.csv to parquet.
# Converted ESML.csv to parquet.
# Converted ESNG.csv to parquet.
# Converted ESPO.csv to parquet.
# Converted ETHO.csv to parquet.
# Converted EUDG.csv to parquet.
# Converted EUDV.csv to parquet.
# Converted EUFN.csv to parquet.
# Converted EUM.csv to parquet.
# Converted EUMF.csv to parquet.
# Converted EUMV.csv to parquet.
# Converted EUO.csv to parquet.
# Converted EURL.csv to parquet.
# Converted EURZ.csv to parquet.
# Converted EUSA.csv to parquet.
# Converted EUSC.csv to parquet.
# Converted EVIX.csv to parquet.
# Converted EVX.csv to parquet.
# Converted EWA.csv to parquet.
# Converted EWC.csv to parquet.
# Converted EWCO.csv to parquet.
# Converted EWD.csv to parquet.
# Converted EWG.csv to parquet.
# Converted EWGS.csv to parquet.
# Converted EWH.csv to parquet.
# Converted EWI.csv to parquet.
# Converted EWJ.csv to parquet.
# Converted EWJE.csv to parquet.
# Converted EWJV.csv to parquet.
# Converted EWK.csv to parquet.
# Converted EWL.csv to parquet.
# Converted EWM.csv to parquet.
# Converted EWMC.csv to parquet.
# Converted EWN.csv to parquet.
# Converted EWO.csv to parquet.
# Converted EWP.csv to parquet.
# Converted EWQ.csv to parquet.
# Converted EWRE.csv to parquet.
# Converted EWS.csv to parquet.
# Converted EWSC.csv to parquet.
# Converted EWT.csv to parquet.
# Converted EWU.csv to parquet.
# Converted EWUS.csv to parquet.
# Converted EWV.csv to parquet.
# Converted EWW.csv to parquet.
# Converted EWX.csv to parquet.
# Converted EWY.csv to parquet.
# Converted EWZ.csv to parquet.
# Converted EWZS.csv to parquet.
# Converted EXI.csv to parquet.
# Converted EXIV.csv to parquet.
# Converted EYLD.csv to parquet.
# Converted EZA.csv to parquet.
# Converted EZJ.csv to parquet.
# Converted EZM.csv to parquet.
# Converted EZU.csv to parquet.
# Converted FAAR.csv to parquet.
# Converted FAB.csv to parquet.
# Converted FAD.csv to parquet.
# Converted FALN.csv to parquet.
# Converted FAN.csv to parquet.
# Converted FAS.csv to parquet.
# Converted FAUG.csv to parquet.
# Converted FAUS.csv to parquet.
# Converted FAZ.csv to parquet.
# Converted FBND.csv to parquet.
# Converted FBT.csv to parquet.
# Converted FBZ.csv to parquet.
# Converted FCA.csv to parquet.
# Converted FCAL.csv to parquet.
# Converted FCAN.csv to parquet.
# Converted FCEF.csv to parquet.
# Converted FCG.csv to parquet.
# Converted FCOM.csv to parquet.
# Converted FCOR.csv to parquet.
# Converted FCPI.csv to parquet.
# Converted FCTR.csv to parquet.
# Converted FCVT.csv to parquet.
# Converted FDD.csv to parquet.
# Converted FDEM.csv to parquet.
# Converted FDEV.csv to parquet.
# Converted FDG.csv to parquet.
# Converted FDHY.csv to parquet.
# Converted FDIS.csv to parquet.
# Converted FDIV.csv to parquet.
# Converted FDL.csv to parquet.
# Converted FDLO.csv to parquet.
# Converted FDM.csv to parquet.
# Converted FDMO.csv to parquet.
# Converted FDN.csv to parquet.
# Converted FDNI.csv to parquet.
# Converted FDRR.csv to parquet.
# Converted FDT.csv to parquet.
# Converted FDTS.csv to parquet.
# Converted FDVV.csv to parquet.
# Converted FEM.csv to parquet.
# Converted FEMB.csv to parquet.
# Converted FEMS.csv to parquet.
# Converted FENY.csv to parquet.
# Converted FEP.csv to parquet.
# Converted FEUZ.csv to parquet.
# Converted FEX.csv to parquet.
# Converted FEZ.csv to parquet.
# Converted FFEB.csv to parquet.
# Converted FFHG.csv to parquet.
# Converted FFIU.csv to parquet.
# Converted FFR.csv to parquet.
# Converted FFSG.csv to parquet.
# Converted FFTG.csv to parquet.
# Converted FFTI.csv to parquet.
# Converted FFTY.csv to parquet.
# Converted FGD.csv to parquet.
# Converted FGM.csv to parquet.
# Converted FHK.csv to parquet.
# Converted FHLC.csv to parquet.
# Converted FIBR.csv to parquet.
# Converted FID.csv to parquet.
# Converted FIDI.csv to parquet.
# Converted FIDU.csv to parquet.
# Converted FILL.csv to parquet.
# Converted FINX.csv to parquet.
# Converted FISR.csv to parquet.
# Converted FITE.csv to parquet.
# Converted FIVA.csv to parquet.
# Converted FIVG.csv to parquet.
# Converted FIW.csv to parquet.
# Converted FIXD.csv to parquet.
# Converted FJNK.csv to parquet.
# Converted FJP.csv to parquet.
# Converted FKO.csv to parquet.
# Converted FKU.csv to parquet.
# Converted FLAG.csv to parquet.
# Converted FLAU.csv to parquet.
# Converted FLAX.csv to parquet.
# Converted FLBL.csv to parquet.
# Converted FLBR.csv to parquet.
# Converted FLCA.csv to parquet.
# Converted FLCB.csv to parquet.
# Converted FLCH.csv to parquet.
# Converted FLCO.csv to parquet.
# Converted FLDR.csv to parquet.
# Converted FLEE.csv to parquet.
# Converted FLEH.csv to parquet.
# Converted FLEU.csv to parquet.
# Converted FLFR.csv to parquet.
# Converted FLGB.csv to parquet.
# Converted FLGR.csv to parquet.
# Converted FLHK.csv to parquet.
# Converted FLHY.csv to parquet.
# Converted FLIA.csv to parquet.
# Converted FLIN.csv to parquet.
# Converted FLIY.csv to parquet.
# Converted FLJH.csv to parquet.
# Converted FLJP.csv to parquet.
# Converted FLKR.csv to parquet.
# Converted FLLA.csv to parquet.
# Converted FLLV.csv to parquet.
# Converted FLM.csv to parquet.
# Converted FLMB.csv to parquet.
# Converted FLMI.csv to parquet.
# Converted FLMX.csv to parquet.
# Converted FLN.csv to parquet.
# Converted FLOT.csv to parquet.
# Converted FLQD.csv to parquet.
# Converted FLQE.csv to parquet.
# Converted FLQG.csv to parquet.
# Converted FLQH.csv to parquet.
# Converted FLQL.csv to parquet.
# Converted FLQM.csv to parquet.
# Converted FLQS.csv to parquet.
# Converted FLRN.csv to parquet.
# Converted FLRT.csv to parquet.
# Converted FLRU.csv to parquet.
# Converted FLSA.csv to parquet.
# Converted FLSP.csv to parquet.
# Converted FLSW.csv to parquet.
# Converted FLTB.csv to parquet.
# Converted FLTR.csv to parquet.
# Converted FLTW.csv to parquet.
# Converted FLYT.csv to parquet.
# Converted FLZA.csv to parquet.
# Converted FM.csv to parquet.
# Converted FMAT.csv to parquet.
# Converted FMB.csv to parquet.
# Converted FMF.csv to parquet.
# Converted FMHI.csv to parquet.
# Converted FMK.csv to parquet.
# Converted FNCL.csv to parquet.
# Converted FNDA.csv to parquet.
# Converted FNDB.csv to parquet.
# Converted FNDC.csv to parquet.
# Converted FNDE.csv to parquet.
# Converted FNDF.csv to parquet.
# Converted FNDX.csv to parquet.
# Converted FNGS.csv to parquet.
# Converted FNI.csv to parquet.
# Converted FNK.csv to parquet.
# Converted FNOV.csv to parquet.
# Converted FNX.csv to parquet.
# Converted FNY.csv to parquet.
# Converted FOVL.csv to parquet.
# Converted FPA.csv to parquet.
# Converted FPE.csv to parquet.
# Converted FPEI.csv to parquet.
# Converted FPX.csv to parquet.
# Converted FPXE.csv to parquet.
# Converted FPXI.csv to parquet.
# Converted FQAL.csv to parquet.
# Converted FRAK.csv to parquet.
# Converted FRDM.csv to parquet.
# Converted FREL.csv to parquet.
# Converted FRI.csv to parquet.
# Converted FSMB.csv to parquet.
# Converted FSMD.csv to parquet.
# Converted FSTA.csv to parquet.
# Converted FSZ.csv to parquet.
# Converted FTA.csv to parquet.
# Converted FTAG.csv to parquet.
# Converted FTC.csv to parquet.
# Converted FTCS.csv to parquet.
# Converted FTEC.csv to parquet.
# Converted FTGC.csv to parquet.
# Converted FTHI.csv to parquet.
# Converted FTLB.csv to parquet.
# Converted FTLS.csv to parquet.
# Converted FTRI.csv to parquet.
# Converted FTSD.csv to parquet.
# Converted FTSL.csv to parquet.
# Converted FTSM.csv to parquet.
# Converted FTXD.csv to parquet.
# Converted FTXG.csv to parquet.
# Converted FTXH.csv to parquet.
# Converted FTXL.csv to parquet.
# Converted FTXN.csv to parquet.
# Converted FTXO.csv to parquet.
# Converted FTXR.csv to parquet.
# Converted FUMB.csv to parquet.
# Converted FUT.csv to parquet.
# Converted FUTY.csv to parquet.
# Converted FV.csv to parquet.
# Converted FVAL.csv to parquet.
# Converted FVC.csv to parquet.
# Converted FVD.csv to parquet.
# Converted FVL.csv to parquet.
# Converted FWDB.csv to parquet.
# Converted FXA.csv to parquet.
# Converted FXB.csv to parquet.
# Converted FXC.csv to parquet.
# Converted FXD.csv to parquet.
# Converted FXE.csv to parquet.
# Converted FXF.csv to parquet.
# Converted FXG.csv to parquet.
# Converted FXH.csv to parquet.
# Converted FXI.csv to parquet.
# Converted FXL.csv to parquet.
# Converted FXN.csv to parquet.
# Converted FXO.csv to parquet.
# Converted FXP.csv to parquet.
# Converted FXR.csv to parquet.
# Converted FXU.csv to parquet.
# Converted FXY.csv to parquet.
# Converted FXZ.csv to parquet.
# Converted FYC.csv to parquet.
# Converted FYLD.csv to parquet.
# Converted FYT.csv to parquet.
# Converted FYX.csv to parquet.
# Converted GAA.csv to parquet.
# Converted GAL.csv to parquet.
# Converted GAMR.csv to parquet.
# Converted GBDV.csv to parquet.
# Converted GBF.csv to parquet.
# Converted GBIL.csv to parquet.
# Converted GBUG.csv to parquet.
# Converted GBUY.csv to parquet.
# Converted GCC.csv to parquet.
# Converted GCOW.csv to parquet.
# Converted GDAT.csv to parquet.
# Converted GDMA.csv to parquet.
# Converted GDNA.csv to parquet.
# Converted GDVD.csv to parquet.
# Converted GDX.csv to parquet.
# Converted GDXJ.csv to parquet.
# Converted GEM.csv to parquet.
# Converted GENY.csv to parquet.
# Converted GFIN.csv to parquet.
# Converted GHYB.csv to parquet.
# Converted GHYG.csv to parquet.
# Converted GIGB.csv to parquet.
# Converted GIGE.csv to parquet.
# Converted GII.csv to parquet.
# Converted GLBY.csv to parquet.
# Converted GLD.csv to parquet.
# Converted GLDM.csv to parquet.
# Converted GLIF.csv to parquet.
# Converted GLL.csv to parquet.
# Converted GLTR.csv to parquet.
# Converted GMAN.csv to parquet.
# Converted GMF.csv to parquet.
# Converted GMOM.csv to parquet.
# Converted GNMA.csv to parquet.
# Converted GNOM.csv to parquet.
# Converted GNR.csv to parquet.
# Converted GOAT.csv to parquet.
# Converted GOAU.csv to parquet.
# Converted GOEX.csv to parquet.
# Converted GOVT.csv to parquet.
# Converted GQRE.csv to parquet.
# Converted GREK.csv to parquet.
# Converted GRES.csv to parquet.
# Converted GRID.csv to parquet.
# Converted GRNB.csv to parquet.
# Converted GSEU.csv to parquet.
# Converted GSEW.csv to parquet.
# Converted GSG.csv to parquet.
# Converted GSIE.csv to parquet.
# Converted GSJY.csv to parquet.
# Converted GSLC.csv to parquet.
# Converted GSSC.csv to parquet.
# Converted GSST.csv to parquet.
# Converted GSY.csv to parquet.
# Converted GTIP.csv to parquet.
# Converted GTO.csv to parquet.
# Converted GUDB.csv to parquet.
# Converted GULF.csv to parquet.
# Converted GUNR.csv to parquet.
# Converted GURU.csv to parquet.
# Converted GUSH.csv to parquet.
# Converted GVAL.csv to parquet.
# Converted GVI.csv to parquet.
# Converted GVIP.csv to parquet.
# Converted GWX.csv to parquet.
# Converted GXC.csv to parquet.
# Converted GXF.csv to parquet.
# Converted GXG.csv to parquet.
# Converted GXTG.csv to parquet.
# Converted GYLD.csv to parquet.
# Converted HACK.csv to parquet.
# Converted HAIL.csv to parquet.
# Converted HAP.csv to parquet.
# Converted HAUD.csv to parquet.
# Converted HAUZ.csv to parquet.
# Converted HAWX.csv to parquet.
# Converted HCRB.csv to parquet.
# Converted HDAW.csv to parquet.
# Converted HDEF.csv to parquet.
# Converted HDG.csv to parquet.
# Converted HDGE.csv to parquet.
# Converted HDIV.csv to parquet.
# Converted HDLB.csv to parquet.
# Converted HDMV.csv to parquet.
# Converted HDV.csv to parquet.
# Converted HECO.csv to parquet.
# Converted HEDJ.csv to parquet.
# Converted HEEM.csv to parquet.
# Converted HEFA.csv to parquet.
# Converted HELX.csv to parquet.
# Converted HERD.csv to parquet.
# Converted HERO.csv to parquet.
# Converted HEWC.csv to parquet.
# Converted HEWG.csv to parquet.
# Converted HEWI.csv to parquet.
# Converted HEWJ.csv to parquet.
# Converted HEWL.csv to parquet.
# Converted HEWP.csv to parquet.
# Converted HEWU.csv to parquet.
# Converted HEWW.csv to parquet.
# Converted HEWY.csv to parquet.
# Converted HEZU.csv to parquet.
# Converted HFXE.csv to parquet.
# Converted HFXI.csv to parquet.
# Converted HFXJ.csv to parquet.
# Converted HIBL.csv to parquet.
# Converted HIBS.csv to parquet.
# Converted HIPS.csv to parquet.
# Converted HJPX.csv to parquet.
# Converted HLAL.csv to parquet.
# Converted HMOP.csv to parquet.
# Converted HNDL.csv to parquet.
# Converted HOLD.csv to parquet.
# Converted HOMZ.csv to parquet.
# Converted HSCZ.csv to parquet.
# Converted HSPX.csv to parquet.
# Converted HSRT.csv to parquet.
# Converted HTAB.csv to parquet.
# Converted HTEC.csv to parquet.
# Converted HTRB.csv to parquet.
# Converted HTUS.csv to parquet.
# Converted HUSE.csv to parquet.
# Converted HUSV.csv to parquet.
# Converted HYD.csv to parquet.
# Converted HYDB.csv to parquet.
# Converted HYDW.csv to parquet.
# Converted HYEM.csv to parquet.
# Converted HYG.csv to parquet.
# Converted HYGH.csv to parquet.
# Converted HYGV.csv to parquet.
# Converted HYHG.csv to parquet.
# Converted HYIH.csv to parquet.
# Converted HYLB.csv to parquet.
# Converted HYLD.csv to parquet.
# Converted HYLS.csv to parquet.
# Converted HYLV.csv to parquet.
# Converted HYMB.csv to parquet.
# Converted HYND.csv to parquet.
# Converted HYS.csv to parquet.
# Converted HYTR.csv to parquet.
# Converted HYUP.csv to parquet.
# Converted HYXE.csv to parquet.
# Converted HYXU.csv to parquet.
# Converted HYZD.csv to parquet.
# Converted IAGG.csv to parquet.
# Converted IAI.csv to parquet.
# Converted IAK.csv to parquet.
# Converted IAT.csv to parquet.
# Converted IAU.csv to parquet.
# Converted IAUF.csv to parquet.
# Converted IBB.csv to parquet.
# Converted IBCE.csv to parquet.
# Converted IBD.csv to parquet.
# Converted IBDD.csv to parquet.
# Converted IBDL.csv to parquet.
# Converted IBDM.csv to parquet.
# Converted IBDN.csv to parquet.
# Converted IBDO.csv to parquet.
# Converted IBDP.csv to parquet.
# Converted IBDQ.csv to parquet.
# Converted IBDR.csv to parquet.
# Converted IBDS.csv to parquet.
# Converted IBDT.csv to parquet.
# Converted IBDU.csv to parquet.
# Converted IBHA.csv to parquet.
# Converted IBHB.csv to parquet.
# Converted IBHC.csv to parquet.
# Converted IBHD.csv to parquet.
# Converted IBHE.csv to parquet.
# Converted IBMI.csv to parquet.
# Converted IBMJ.csv to parquet.
# Converted IBMK.csv to parquet.
# Converted IBML.csv to parquet.
# Converted IBMM.csv to parquet.
# Converted IBMN.csv to parquet.
# Converted IBMO.csv to parquet.
# Converted IBMP.csv to parquet.
# Converted IBMQ.csv to parquet.
# Converted IBND.csv to parquet.
# Converted IBTE.csv to parquet.
# Converted IBTF.csv to parquet.
# Converted IBTG.csv to parquet.
# Converted IBTH.csv to parquet.
# Converted IBTI.csv to parquet.
# Converted IBTJ.csv to parquet.
# Converted IBUY.csv to parquet.
# Converted ICF.csv to parquet.
# Converted ICLN.csv to parquet.
# Converted ICOL.csv to parquet.
# Converted ICOW.csv to parquet.
# Converted ICSH.csv to parquet.
# Converted ICVT.csv to parquet.
# Converted IDEV.csv to parquet.
# Converted IDHD.csv to parquet.
# Converted IDHQ.csv to parquet.
# Converted IDIV.csv to parquet.
# Converted IDLB.csv to parquet.
# Converted IDLV.csv to parquet.
# Converted IDMO.csv to parquet.
# Converted IDNA.csv to parquet.
# Converted IDOG.csv to parquet.
# Converted IDRV.csv to parquet.
# Converted IDU.csv to parquet.
# Converted IDV.csv to parquet.
# Converted IDX.csv to parquet.
# Converted IDY.csv to parquet.
# Converted IECS.csv to parquet.
# Converted IEDI.csv to parquet.
# Converted IEF.csv to parquet.
# Converted IEFA.csv to parquet.
# Converted IEFN.csv to parquet.
# Converted IEHS.csv to parquet.
# Converted IEI.csv to parquet.
# Converted IEIH.csv to parquet.
# Converted IEME.csv to parquet.
# Converted IEMG.csv to parquet.
# Converted IEO.csv to parquet.
# Converted IETC.csv to parquet.
# Converted IEUR.csv to parquet.
# Converted IEUS.csv to parquet.
# Converted IEV.csv to parquet.
# Converted IEZ.csv to parquet.
# Converted IFEU.csv to parquet.
# Converted IFGL.csv to parquet.
# Converted IFLY.csv to parquet.
# Converted IFRA.csv to parquet.
# Converted IFV.csv to parquet.
# Converted IG.csv to parquet.
# Converted IGBH.csv to parquet.
# Converted IGE.csv to parquet.
# Converted IGEB.csv to parquet.
# Converted IGF.csv to parquet.
# Converted IGHG.csv to parquet.
# Converted IGIB.csv to parquet.
# Converted IGIH.csv to parquet.
# Converted IGLB.csv to parquet.
# Converted IGM.csv to parquet.
# Converted IGN.csv to parquet.
# Converted IGOV.csv to parquet.
# Converted IGRO.csv to parquet.
# Converted IGSB.csv to parquet.
# Converted IGV.csv to parquet.
# Converted IHAK.csv to parquet.
# Converted IHDG.csv to parquet.
# Converted IHE.csv to parquet.
# Converted IHF.csv to parquet.
# Converted IHI.csv to parquet.
# Converted IHY.csv to parquet.
# Converted IIGD.csv to parquet.
# Converted IIGV.csv to parquet.
# Converted IJAN.csv to parquet.
# Converted IJH.csv to parquet.
# Converted IJJ.csv to parquet.
# Converted IJK.csv to parquet.
# Converted IJR.csv to parquet.
# Converted IJS.csv to parquet.
# Converted IJT.csv to parquet.
# Converted IJUL.csv to parquet.
# Converted ILF.csv to parquet.
# Converted ILTB.csv to parquet.
# Converted IMOM.csv to parquet.
# Converted IMTB.csv to parquet.
# Converted IMTM.csv to parquet.
# Converted INCO.csv to parquet.
# Converted INDA.csv to parquet.
# Converted INDL.csv to parquet.
# Converted INDS.csv to parquet.
# Converted INDY.csv to parquet.
# Converted INFR.csv to parquet.
# Converted INKM.csv to parquet.
# Converted INTF.csv to parquet.
# Converted IOO.csv to parquet.
# Converted IPAC.csv to parquet.
# Converted IPAY.csv to parquet.
# Converted IPB.csv to parquet.
# Converted IPFF.csv to parquet.
# Converted IPKW.csv to parquet.
# Converted IPO.csv to parquet.
# Converted IPOS.csv to parquet.
# Converted IQDE.csv to parquet.
# Converted IQDF.csv to parquet.
# Converted IQDG.csv to parquet.
# Converted IQDY.csv to parquet.
# Converted IQIN.csv to parquet.
# Converted IQLT.csv to parquet.
# Converted IQM.csv to parquet.
# Converted IQSI.csv to parquet.
# Converted IQSU.csv to parquet.
# Converted IRBO.csv to parquet.
# Converted ISCF.csv to parquet.
# Converted ISDS.csv to parquet.
# Converted ISDX.csv to parquet.
# Converted ISEM.csv to parquet.
# Converted ISHG.csv to parquet.
# Converted ISMD.csv to parquet.
# Converted ISRA.csv to parquet.
# Converted ISTB.csv to parquet.
# Converted ISZE.csv to parquet.
# Converted ITA.csv to parquet.
# Converted ITB.csv to parquet.
# Converted ITEQ.csv to parquet.
# Converted ITM.csv to parquet.
# Converted ITOT.csv to parquet.
# Converted IUS.csv to parquet.
# Converted IUSB.csv to parquet.
# Converted IUSG.csv to parquet.
# Converted IUSS.csv to parquet.
# Converted IUSV.csv to parquet.
# Converted IVAL.csv to parquet.
# Converted IVE.csv to parquet.
# Converted IVLU.csv to parquet.
# Converted IVOG.csv to parquet.
# Converted IVOL.csv to parquet.
# Converted IVOO.csv to parquet.
# Converted IVOV.csv to parquet.
# Converted IVV.csv to parquet.
# Converted IVW.csv to parquet.
# Converted IWB.csv to parquet.
# Converted IWC.csv to parquet.
# Converted IWD.csv to parquet.
# Converted IWF.csv to parquet.
# Converted IWL.csv to parquet.
# Converted IWM.csv to parquet.
# Converted IWN.csv to parquet.
# Converted IWO.csv to parquet.
# Converted IWP.csv to parquet.
# Converted IWR.csv to parquet.
# Converted IWS.csv to parquet.
# Converted IWV.csv to parquet.
# Converted IWX.csv to parquet.
# Converted IWY.csv to parquet.
# Converted IXC.csv to parquet.
# Converted IXG.csv to parquet.
# Converted IXJ.csv to parquet.
# Converted IXN.csv to parquet.
# Converted IXP.csv to parquet.
# Converted IXSE.csv to parquet.
# Converted IXUS.csv to parquet.
# Converted IYC.csv to parquet.
# Converted IYE.csv to parquet.
# Converted IYF.csv to parquet.
# Converted IYG.csv to parquet.
# Converted IYH.csv to parquet.
# Converted IYJ.csv to parquet.
# Converted IYK.csv to parquet.
# Converted IYLD.csv to parquet.
# Converted IYM.csv to parquet.
# Converted IYR.csv to parquet.
# Converted IYT.csv to parquet.
# Converted IYW.csv to parquet.
# Converted IYY.csv to parquet.
# Converted IYZ.csv to parquet.
# Converted IZRL.csv to parquet.
# Converted JAGG.csv to parquet.
# Converted JCPB.csv to parquet.
# Converted JDIV.csv to parquet.
# Converted JDST.csv to parquet.
# Converted JETS.csv to parquet.
# Converted JHCS.csv to parquet.
# Converted JHEM.csv to parquet.
# Converted JHMA.csv to parquet.
# Converted JHMC.csv to parquet.
# Converted JHMD.csv to parquet.
# Converted JHME.csv to parquet.
# Converted JHMF.csv to parquet.
# Converted JHMH.csv to parquet.
# Converted JHMI.csv to parquet.
# Converted JHML.csv to parquet.
# Converted JHMM.csv to parquet.
# Converted JHMS.csv to parquet.
# Converted JHMT.csv to parquet.
# Converted JHMU.csv to parquet.
# Converted JHSC.csv to parquet.
# Converted JIGB.csv to parquet.
# Converted JKD.csv to parquet.
# Converted JKE.csv to parquet.
# Converted JKF.csv to parquet.
# Converted JKG.csv to parquet.
# Converted JKH.csv to parquet.
# Converted JKI.csv to parquet.
# Converted JKJ.csv to parquet.
# Converted JKK.csv to parquet.
# Converted JKL.csv to parquet.
# Converted JMBS.csv to parquet.
# Converted JMIN.csv to parquet.
# Converted JMOM.csv to parquet.
# Converted JMST.csv to parquet.
# Converted JMUB.csv to parquet.
# Converted JNK.csv to parquet.
# Converted JNMF.csv to parquet.
# Converted JNUG.csv to parquet.
# Converted JOYY.csv to parquet.
# Converted JPED.csv to parquet.
# Converted JPEM.csv to parquet.
# Converted JPEU.csv to parquet.
# Converted JPGB.csv to parquet.
# Converted JPGE.csv to parquet.
# Converted JPHF.csv to parquet.
# Converted JPHY.csv to parquet.
# Converted JPIN.csv to parquet.
# Converted JPLS.csv to parquet.
# Converted JPMB.csv to parquet.
# Converted JPME.csv to parquet.
# Converted JPMF.csv to parquet.
# Converted JPMV.csv to parquet.
# Converted JPN.csv to parquet.
# Converted JPNL.csv to parquet.
# Converted JPSE.csv to parquet.
# Converted JPST.csv to parquet.
# Converted JPUS.csv to parquet.
# Converted JPXN.csv to parquet.
# Converted JQUA.csv to parquet.
# Converted JSMD.csv to parquet.
# Converted JSML.csv to parquet.
# Converted JUST.csv to parquet.
# Converted JVAL.csv to parquet.
# Converted JXI.csv to parquet.
# Converted KALL.csv to parquet.
# Converted KARS.csv to parquet.
# Converted KBA.csv to parquet.
# Converted KBE.csv to parquet.
# Converted KBWB.csv to parquet.
# Converted KBWD.csv to parquet.
# Converted KBWP.csv to parquet.
# Converted KBWR.csv to parquet.
# Converted KBWY.csv to parquet.
# Converted KCCB.csv to parquet.
# Converted KCE.csv to parquet.
# Converted KCNY.csv to parquet.
# Converted KDFI.csv to parquet.
# Converted KEMQ.csv to parquet.
# Converted KEMX.csv to parquet.
# Converted KFYP.csv to parquet.
# Converted KGRN.csv to parquet.
# Converted KIE.csv to parquet.
# Converted KJAN.csv to parquet.
# Converted KLCD.csv to parquet.
# Converted KLDW.csv to parquet.
# Converted KMED.csv to parquet.
# Converted KNG.csv to parquet.
# Converted KNOW.csv to parquet.
# Converted KOCT.csv to parquet.
# Converted KOIN.csv to parquet.
# Converted KOL.csv to parquet.
# Converted KOLD.csv to parquet.
# Converted KOMP.csv to parquet.
# Converted KORP.csv to parquet.
# Converted KORU.csv to parquet.
# Converted KRE.csv to parquet.
# Converted KRMA.csv to parquet.
# Converted KSA.csv to parquet.
# Converted KSCD.csv to parquet.
# Converted KURE.csv to parquet.
# Converted KWEB.csv to parquet.
# Converted KXI.csv to parquet.
# Converted LABD.csv to parquet.
# Converted LABU.csv to parquet.
# Converted LACK.csv to parquet.
# Converted LBJ.csv to parquet.
# Converted LCR.csv to parquet.
# Converted LDEM.csv to parquet.
# Converted LDRS.csv to parquet.
# Converted LDSF.csv to parquet.
# Converted LDUR.csv to parquet.
# Converted LEAD.csv to parquet.
# Converted LEGR.csv to parquet.
# Converted LEMB.csv to parquet.
# Converted LEND.csv to parquet.
# Converted LFEQ.csv to parquet.
# Converted LGH.csv to parquet.
# Converted LGLV.csv to parquet.
# Converted LGOV.csv to parquet.
# Converted LIT.csv to parquet.
# Converted LKOR.csv to parquet.
# Converted LMBS.csv to parquet.
# Converted LMLB.csv to parquet.
# Converted LNGR.csv to parquet.
# Converted LOUP.csv to parquet.
# Converted LOWC.csv to parquet.
# Converted LQD.csv to parquet.
# Converted LQDH.csv to parquet.
# Converted LQDI.csv to parquet.
# Converted LRGE.csv to parquet.
# Converted LRGF.csv to parquet.
# Converted LRNZ.csv to parquet.
# Converted LSAF.csv to parquet.
# Converted LSLT.csv to parquet.
# Converted LSST.csv to parquet.
# Converted LTL.csv to parquet.
# Converted LTPZ.csv to parquet.
# Converted LVHB.csv to parquet.
# Converted LVHD.csv to parquet.
# Converted LVHE.csv to parquet.
# Converted LVHI.csv to parquet.
# Converted LVUS.csv to parquet.
# Converted MAAX.csv to parquet.
# Converted MAGA.csv to parquet.
# Converted MARB.csv to parquet.
# Converted MBB.csv to parquet.
# Converted MBSD.csv to parquet.
# Converted MCEF.csv to parquet.
# Converted MCHI.csv to parquet.
# Converted MCRO.csv to parquet.
# Converted MDIV.csv to parquet.
# Converted MDY.csv to parquet.
# Converted MDYG.csv to parquet.
# Converted MDYV.csv to parquet.
# Converted MEAR.csv to parquet.
# Converted MEXX.csv to parquet.
# Converted MFDX.csv to parquet.
# Converted MFEM.csv to parquet.
# Converted MFMS.csv to parquet.
# Converted MFUS.csv to parquet.
# Converted MGC.csv to parquet.
# Converted MGK.csv to parquet.
# Converted MGV.csv to parquet.
# Converted MIDF.csv to parquet.
# Converted MIDU.csv to parquet.
# Converted MILN.csv to parquet.
# Converted MINC.csv to parquet.
# Converted MINT.csv to parquet.
# Converted MJ.csv to parquet.
# Converted MJJ.csv to parquet.
# Converted MJO.csv to parquet.
# Converted MLN.csv to parquet.
# Converted MLPA.csv to parquet.
# Converted MLPX.csv to parquet.
# Converted MLTI.csv to parquet.
# Converted MMIN.csv to parquet.
# Converted MMIT.csv to parquet.
# Converted MMTM.csv to parquet.
# Converted MNA.csv to parquet.
# Converted MOAT.csv to parquet.
# Converted MOM.csv to parquet.
# Converted MOO.csv to parquet.
# Converted MORT.csv to parquet.
# Converted MOTI.csv to parquet.
# Converted MOTO.csv to parquet.
# Converted MRGR.csv to parquet.
# Converted MSUS.csv to parquet.
# Converted MTGP.csv to parquet.
# Converted MTUM.csv to parquet.
# Converted MUB.csv to parquet.
# Converted MUNI.csv to parquet.
# Converted MUST.csv to parquet.
# Converted MUTE.csv to parquet.
# Converted MVIN.csv to parquet.
# Converted MVV.csv to parquet.
# Converted MXDE.csv to parquet.
# Converted MXDU.csv to parquet.
# Converted MXI.csv to parquet.
# Converted MYY.csv to parquet.
# Converted MZZ.csv to parquet.
# Converted NACP.csv to parquet.
# Converted NAIL.csv to parquet.
# Converted NANR.csv to parquet.
# Converted NEAR.csv to parquet.
# Converted NEED.csv to parquet.
# Converted NERD.csv to parquet.
# Converted NETL.csv to parquet.
# Converted NFLT.csv to parquet.
# Converted NFRA.csv to parquet.
# Converted NFTY.csv to parquet.
# Converted NGE.csv to parquet.
# Converted NJAN.csv to parquet.
# Converted NLR.csv to parquet.
# Converted NOBL.csv to parquet.
# Converted NOCT.csv to parquet.
# Converted NORW.csv to parquet.
# Converted NTSX.csv to parquet.
# Converted NUAG.csv to parquet.
# Converted NUBD.csv to parquet.
# Converted NUDM.csv to parquet.
# Converted NUEM.csv to parquet.
# Converted NUGT.csv to parquet.
# Converted NUHY.csv to parquet.
# Converted NULC.csv to parquet.
# Converted NULG.csv to parquet.
# Converted NULV.csv to parquet.
# Converted NUMG.csv to parquet.
# Converted NUMV.csv to parquet.
# Converted NURE.csv to parquet.
# Converted NUSA.csv to parquet.
# Converted NUSC.csv to parquet.
# Converted NUSI.csv to parquet.
# Converted NXTG.csv to parquet.
# Converted NYF.csv to parquet.
# Converted OBOR.csv to parquet.
# Converted OCIO.csv to parquet.
# Converted OEF.csv to parquet.
# Converted OEUR.csv to parquet.
# Converted OGIG.csv to parquet.
# Converted OIH.csv to parquet.
# Converted OIL.csv to parquet.
# Converted OILK.csv to parquet.
# Converted OLD.csv to parquet.
# Converted OMFL.csv to parquet.
# Converted OMFS.csv to parquet.
# Converted ONEO.csv to parquet.
# Converted ONEQ.csv to parquet.
# Converted ONEV.csv to parquet.
# Converted ONEY.csv to parquet.
# Converted ONLN.csv to parquet.
# Converted OPER.csv to parquet.
# Converted OSCV.csv to parquet.
# Converted OUNZ.csv to parquet.
# Converted OUSA.csv to parquet.
# Converted OUSM.csv to parquet.
# Converted OVB.csv to parquet.
# Converted OVF.csv to parquet.
# Converted OVL.csv to parquet.
# Converted OVM.csv to parquet.
# Converted OVS.csv to parquet.
# Converted PACA.csv to parquet.
# Converted PAK.csv to parquet.
# Converted PALL.csv to parquet.
# Converted PAPR.csv to parquet.
# Converted PASS.csv to parquet.
# Converted PAUG.csv to parquet.
# Converted PAVE.csv to parquet.
# Converted PAWZ.csv to parquet.
# Converted PBD.csv to parquet.
# Converted PBDM.csv to parquet.
# Converted PBE.csv to parquet.
# Converted PBEE.csv to parquet.
# Converted PBJ.csv to parquet.
# Converted PBND.csv to parquet.
# Converted PBP.csv to parquet.
# Converted PBS.csv to parquet.
# Converted PBSM.csv to parquet.
# Converted PBTP.csv to parquet.
# Converted PBUS.csv to parquet.
# Converted PBW.csv to parquet.
# Converted PCEF.csv to parquet.
# Converted PCY.csv to parquet.
# Converted PDBC.csv to parquet.
# Converted PDEC.csv to parquet.
# Converted PDEV.csv to parquet.
# Converted PDN.csv to parquet.
# Converted PDP.csv to parquet.
# Converted PEJ.csv to parquet.
# Converted PEK.csv to parquet.
# Converted PEX.csv to parquet.
# Converted PEXL.csv to parquet.
# Converted PEY.csv to parquet.
# Converted PEZ.csv to parquet.
# Converted PFEB.csv to parquet.
# Converted PFF.csv to parquet.
# Converted PFFA.csv to parquet.
# Converted PFFD.csv to parquet.
# Converted PFFR.csv to parquet.
# Converted PFI.csv to parquet.
# Converted PFIG.csv to parquet.
# Converted PFLD.csv to parquet.
# Converted PFM.csv to parquet.
# Converted PFXF.csv to parquet.
# Converted PGAL.csv to parquet.
# Converted PGF.csv to parquet.
# Converted PGHY.csv to parquet.
# Converted PGJ.csv to parquet.
# Converted PGX.csv to parquet.
# Converted PHB.csv to parquet.
# Converted PHDG.csv to parquet.
# Converted PHO.csv to parquet.
# Converted PHYL.csv to parquet.
# Converted PHYS.csv to parquet.
# Converted PICB.csv to parquet.
# Converted PICK.csv to parquet.
# Converted PID.csv to parquet.
# Converted PIE.csv to parquet.
# Converted PILL.csv to parquet.
# Converted PIN.csv to parquet.
# Converted PIO.csv to parquet.
# Converted PIZ.csv to parquet.
# Converted PJAN.csv to parquet.
# Converted PJP.csv to parquet.
# Converted PJUL.csv to parquet.
# Converted PJUN.csv to parquet.
# Converted PKB.csv to parquet.
# Converted PKW.csv to parquet.
# Converted PLAT.csv to parquet.
# Converted PLC.csv to parquet.
# Converted PLCY.csv to parquet.
# Converted PLTM.csv to parquet.
# Converted PLW.csv to parquet.
# Converted PMAR.csv to parquet.
# Converted PMOM.csv to parquet.
# Converted PNOV.csv to parquet.
# Converted PNQI.csv to parquet.
# Converted POCT.csv to parquet.
# Converted POTX.csv to parquet.
# Converted PPA.csv to parquet.
# Converted PPDM.csv to parquet.
# Converted PPEM.csv to parquet.
# Converted PPH.csv to parquet.
# Converted PPLC.csv to parquet.
# Converted PPLT.csv to parquet.
# Converted PPMC.csv to parquet.
# Converted PPSC.csv to parquet.
# Converted PPTY.csv to parquet.
# Converted PQIN.csv to parquet.
# Converted PQLC.csv to parquet.
# Converted PQSG.csv to parquet.
# Converted PQSV.csv to parquet.
# Converted PREF.csv to parquet.
# Converted PRF.csv to parquet.
# Converted PRFZ.csv to parquet.
# Converted PRN.csv to parquet.
# Converted PRNT.csv to parquet.
# Converted PSC.csv to parquet.
# Converted PSCC.csv to parquet.
# Converted PSCD.csv to parquet.
# Converted PSCE.csv to parquet.
# Converted PSCF.csv to parquet.
# Converted PSCH.csv to parquet.
# Converted PSCI.csv to parquet.
# Converted PSCM.csv to parquet.
# Converted PSCT.csv to parquet.
# Converted PSCU.csv to parquet.
# Converted PSEP.csv to parquet.
# Converted PSET.csv to parquet.
# Converted PSI.csv to parquet.
# Converted PSJ.csv to parquet.
# Converted PSK.csv to parquet.
# Converted PSL.csv to parquet.
# Converted PSLV.csv to parquet.
# Converted PSM.csv to parquet.
# Converted PSMB.csv to parquet.
# Converted PSMC.csv to parquet.
# Converted PSMG.csv to parquet.
# Converted PSMM.csv to parquet.
# Converted PSP.csv to parquet.
# Converted PSQ.csv to parquet.
# Converted PSR.csv to parquet.
# Converted PST.csv to parquet.
# Converted PTBD.csv to parquet.
# Converted PTEU.csv to parquet.
# Converted PTF.csv to parquet.
# Converted PTH.csv to parquet.
# Converted PTIN.csv to parquet.
# Converted PTLC.csv to parquet.
# Converted PTMC.csv to parquet.
# Converted PTNQ.csv to parquet.
# Converted PUI.csv to parquet.
# Converted PULS.csv to parquet.
# Converted PUTW.csv to parquet.
# Converted PVAL.csv to parquet.
# Converted PVI.csv to parquet.
# Converted PWB.csv to parquet.
# Converted PWC.csv to parquet.
# Converted PWS.csv to parquet.
# Converted PWV.csv to parquet.
# Converted PWZ.csv to parquet.
# Converted PXE.csv to parquet.
# Converted PXF.csv to parquet.
# Converted PXH.csv to parquet.
# Converted PXI.csv to parquet.
# Converted PXJ.csv to parquet.
# Converted PXQ.csv to parquet.
# Converted PY.csv to parquet.
# Converted PYZ.csv to parquet.
# Converted PZA.csv to parquet.
# Converted PZD.csv to parquet.
# Converted PZT.csv to parquet.
# Converted QABA.csv to parquet.
# Converted QAI.csv to parquet.
# Converted QARP.csv to parquet.
# Converted QAT.csv to parquet.
# Converted QCLN.csv to parquet.
# Converted QDEF.csv to parquet.
# Converted QDF.csv to parquet.
# Converted QDIV.csv to parquet.
# Converted QDYN.csv to parquet.
# Converted QED.csv to parquet.
# Converted QEFA.csv to parquet.
# Converted QEMM.csv to parquet.
# Converted QGRO.csv to parquet.
# Converted QGTA.csv to parquet.
# Converted QID.csv to parquet.
# Converted QINT.csv to parquet.
# Converted QLC.csv to parquet.
# Converted QLD.csv to parquet.
# Converted QLS.csv to parquet.
# Converted QLTA.csv to parquet.
# Converted QLV.csv to parquet.
# Converted QLVD.csv to parquet.
# Converted QLVE.csv to parquet.
# Converted QMJ.csv to parquet.
# Converted QMN.csv to parquet.
# Converted QMOM.csv to parquet.
# Converted QQEW.csv to parquet.
# Converted QQH.csv to parquet.
# Converted QQQ.csv to parquet.
# Converted QQQE.csv to parquet.
# Converted QQXT.csv to parquet.
# Converted QRFT.csv to parquet.
# Converted QSY.csv to parquet.
# Converted QTEC.csv to parquet.
# Converted QTUM.csv to parquet.
# Converted QUAL.csv to parquet.
# Converted QUS.csv to parquet.
# Converted QVAL.csv to parquet.
# Converted QVM.csv to parquet.
# Converted QWLD.csv to parquet.
# Converted QYLD.csv to parquet.
# Converted RAAX.csv to parquet.
# Converted RAFE.csv to parquet.
# Converted RALS.csv to parquet.
# Converted RAVI.csv to parquet.
# Converted RBIN.csv to parquet.
# Converted RBUS.csv to parquet.
# Converted RCD.csv to parquet.
# Converted RDIV.csv to parquet.
# Converted RDOG.csv to parquet.
# Converted RDVY.csv to parquet.
# Converted RECS.csv to parquet.
# Converted REET.csv to parquet.
# Converted REGL.csv to parquet.
# Converted REK.csv to parquet.
# Converted REM.csv to parquet.
# Converted REMX.csv to parquet.
# Converted RESD.csv to parquet.
# Converted RESE.csv to parquet.
# ...
# Converted TWO.csv to parquet.
# Converted TWOU.csv to parquet.
# Converted TWST.csv to parquet.
# Converted TWTR.csv to parquet.
# Converted TX.csv to parquet.
# Converted TXG.csv to parquet.
# Converted TXMD.csv to parquet.
# Converted TXN.csv to parquet.
# Converted TXRH.csv to parquet.
# Converted TXT.csv to parquet.
# Converted TY.csv to parquet.
# Converted TYG.csv to parquet.
# Converted TYHT.csv to parquet.
# Converted TYL.csv to parquet.
# Converted TYME.csv to parquet.
# Converted TZAC.csv to parquet.
# Converted TZACU.csv to parquet.
# Converted TZOO.csv to parquet.
# Converted UA.csv to parquet.
# Converted UAA.csv to parquet.
# Converted UAG.csv to parquet.
# Converted UAL.csv to parquet.
# Converted UAMY.csv to parquet.
# Converted UAN.csv to parquet.
# Converted UAUD.csv to parquet.
# Converted UAVS.csv to parquet.
# Converted UBA.csv to parquet.
# Converted UBCP.csv to parquet.
# Converted UBER.csv to parquet.
# Converted UBFO.csv to parquet.
# Converted UBG.csv to parquet.
# Converted UBOH.csv to parquet.
# Converted UBP.csv to parquet.
# Converted UBS.csv to parquet.
# Converted UBSI.csv to parquet.
# Converted UBX.csv to parquet.
# Converted UCBI.csv to parquet.
# Converted UCHF.csv to parquet.
# Converted UCI.csv to parquet.
# Converted UCIB.csv to parquet.
# Converted UCTT.csv to parquet.
# Converted UDR.csv to parquet.
# Converted UE.csv to parquet.
# Converted UEC.csv to parquet.
# Converted UEIC.csv to parquet.
# Converted UEPS.csv to parquet.
# Converted UEUR.csv to parquet.
# Converted UFAB.csv to parquet.
# Converted UFCS.csv to parquet.
# Converted UFI.csv to parquet.
# Converted UFPI.csv to parquet.
# Converted UFPT.csv to parquet.
# Converted UFS.csv to parquet.
# Converted UG.csv to parquet.
# Converted UGAZ.csv to parquet.
# Converted UGBP.csv to parquet.
# Converted UGI.csv to parquet.
# Converted UGLD.csv to parquet.
# Converted UGP.csv to parquet.
# Converted UHAL.csv to parquet.
# Converted UHS.csv to parquet.
# Converted UHT.csv to parquet.
# Converted UI.csv to parquet.
# Converted UIHC.csv to parquet.
# Converted UIS.csv to parquet.
# Converted UJPY.csv to parquet.
# Converted UL.csv to parquet.
# Converted ULBI.csv to parquet.
# Converted ULH.csv to parquet.
# Converted ULTA.csv to parquet.
# Converted UMBF.csv to parquet.
# Converted UMC.csv to parquet.
# Converted UMH.csv to parquet.
# Converted UMPQ.csv to parquet.
# Converted UMRX.csv to parquet.
# Converted UN.csv to parquet.
# Converted UNAM.csv to parquet.
# Converted UNB.csv to parquet.
# Converted UNF.csv to parquet.
# Converted UNFI.csv to parquet.
# Converted UNH.csv to parquet.
# Converted UNIT.csv to parquet.
# Converted UNM.csv to parquet.
# Converted UNMA.csv to parquet.
# Converted UNP.csv to parquet.
# Converted UNT.csv to parquet.
# Converted UNTY.csv to parquet.
# Converted UNVR.csv to parquet.
# Converted UONE.csv to parquet.
# Converted UONEK.csv to parquet.
# Converted UPLD.csv to parquet.
# Converted UPS.csv to parquet.
# Converted UPWK.csv to parquet.
# Converted URBN.csv to parquet.
# Converted URG.csv to parquet.
# Converted URGN.csv to parquet.
# Converted URI.csv to parquet.
# Converted UROV.csv to parquet.
# Converted URR.csv to parquet.
# Converted USA.csv to parquet.
# Converted USAC.csv to parquet.
# Converted USAK.csv to parquet.
# Converted USAP.csv to parquet.
# Converted USAS.csv to parquet.
# Converted USAU.csv to parquet.
# Converted USB.csv to parquet.
# Converted USCR.csv to parquet.
# Converted USDP.csv to parquet.
# Converted USEG.csv to parquet.
# Converted USFD.csv to parquet.
# Converted USIO.csv to parquet.
# Converted USLM.csv to parquet.
# Converted USLV.csv to parquet.
# Converted USM.csv to parquet.
# Converted USNA.csv to parquet.
# Converted USOI.csv to parquet.
# Converted USPH.csv to parquet.
# Converted USV.csv to parquet.
# Converted USWS.csv to parquet.
# Converted USX.csv to parquet.
# Converted UTF.csv to parquet.
# Converted UTG.csv to parquet.
# Converted UTHR.csv to parquet.
# Converted UTI.csv to parquet.
# Converted UTL.csv to parquet.
# Converted UTMD.csv to parquet.
# Converted UTSI.csv to parquet.
# Converted UTX#.csv to parquet.
# Converted UTX.csv to parquet.
# Converted UUU.csv to parquet.
# Converted UUUU.csv to parquet.
# Converted UVE.csv to parquet.
# Converted UVSP.csv to parquet.
# Converted UVV.csv to parquet.
# Converted UXIN.csv to parquet.
# Converted UZA.csv to parquet.
# Converted UZB.csv to parquet.
# Converted UZC.csv to parquet.
# Converted V.csv to parquet.
# Converted VAC.csv to parquet.
# Converted VAL.csv to parquet.
# Converted VALE.csv to parquet.
# Converted VALU.csv to parquet.
# Converted VAM.csv to parquet.
# Converted VAPO.csv to parquet.
# Converted VAR.csv to parquet.
# Converted VBF.csv to parquet.
# Converted VBFC.csv to parquet.
# Converted VBIV.csv to parquet.
# Converted VBLT.csv to parquet.
# Converted VBTX.csv to parquet.
# Converted VC.csv to parquet.
# Converted VCEL.csv to parquet.
# Converted VCF.csv to parquet.
# Converted VCIF.csv to parquet.
# Converted VCNX.csv to parquet.
# Converted VCRA.csv to parquet.
# Converted VCTR.csv to parquet.
# Converted VCV.csv to parquet.
# Converted VCYT.csv to parquet.
# Converted VEC.csv to parquet.
# Converted VECO.csv to parquet.
# Converted VEDL.csv to parquet.
# Converted VEEV.csv to parquet.
# Converted VEL.csv to parquet.
# Converted VEON.csv to parquet.
# Converted VER.csv to parquet.
# Converted VERB.csv to parquet.
# Converted VERI.csv to parquet.
# Converted VERO.csv to parquet.
# Converted VERU.csv to parquet.
# Converted VERY.csv to parquet.
# Converted VET.csv to parquet.
# Converted VFC.csv to parquet.
# Converted VFF.csv to parquet.
# Converted VFL.csv to parquet.
# Converted VG.csv to parquet.
# Converted VGI.csv to parquet.
# Converted VGM.csv to parquet.
# Converted VGR.csv to parquet.
# Converted VGZ.csv to parquet.
# Converted VHC.csv to parquet.
# Converted VHI.csv to parquet.
# Converted VIAC.csv to parquet.
# Converted VIACA.csv to parquet.
# Converted VIAV.csv to parquet.
# Converted VICI.csv to parquet.
# Converted VICR.csv to parquet.
# Converted VIE.csv to parquet.
# Converted VIIX.csv to parquet.
# Converted VIOT.csv to parquet.
# Converted VIPS.csv to parquet.
# Converted VIR.csv to parquet.
# Converted VIRC.csv to parquet.
# Converted VIRT.csv to parquet.
# Converted VISL.csv to parquet.
# Converted VIST.csv to parquet.
# Converted VIV.csv to parquet.
# Converted VIVE.csv to parquet.
# Converted VIVO.csv to parquet.
# Converted VJET.csv to parquet.
# Converted VKI.csv to parquet.
# Converted VKQ.csv to parquet.
# Converted VKTX.csv to parquet.
# Converted VLGEA.csv to parquet.
# Converted VLO.csv to parquet.
# Converted VLRS.csv to parquet.
# Converted VLT.csv to parquet.
# Converted VLY.csv to parquet.
# Converted VLYPO.csv to parquet.
# Converted VLYPP.csv to parquet.
# Converted VMC.csv to parquet.
# Converted VMD.csv to parquet.
# Converted VMI.csv to parquet.
# Converted VMM.csv to parquet.
# Converted VMO.csv to parquet.
# Converted VMW.csv to parquet.
# Converted VNCE.csv to parquet.
# Converted VNDA.csv to parquet.
# Converted VNE.csv to parquet.
# Converted VNET.csv to parquet.
# Converted VNO.csv to parquet.
# Converted VNOM.csv to parquet.
# Converted VNRX.csv to parquet.
# Converted VNTR.csv to parquet.
# Converted VOC.csv to parquet.
# Converted VOD.csv to parquet.
# Converted VOLT.csv to parquet.
# Converted VOXX.csv to parquet.
# Converted VOYA.csv to parquet.
# Converted VPG.csv to parquet.
# Converted VPV.csv to parquet.
# Converted VQT.csv to parquet.
# Converted VRA.csv to parquet.
# Converted VRAY.csv to parquet.
# Converted VRCA.csv to parquet.
# Converted VREX.csv to parquet.
# Converted VRML.csv to parquet.
# Converted VRNA.csv to parquet.
# Converted VRNS.csv to parquet.
# Converted VRNT.csv to parquet.
# Converted VRRM.csv to parquet.
# Converted VRS.csv to parquet.
# Converted VRSK.csv to parquet.
# Converted VRSN.csv to parquet.
# Converted VRT.csv to parquet.
# Converted VRTS.csv to parquet.
# Converted VRTU.csv to parquet.
# Converted VRTV.csv to parquet.
# Converted VRTX.csv to parquet.
# Converted VSAT.csv to parquet.
# Converted VSEC.csv to parquet.
# Converted VSH.csv to parquet.
# Converted VSLR.csv to parquet.
# Converted VST.csv to parquet.
# Converted VSTM.csv to parquet.
# Converted VSTO.csv to parquet.
# Converted VTA.csv to parquet.
# Converted VTGN.csv to parquet.
# Converted VTIQ.csv to parquet.
# Converted VTIQU.csv to parquet.
# Converted VTIQW.csv to parquet.
# Converted VTN.csv to parquet.
# Converted VTNR.csv to parquet.
# Converted VTR.csv to parquet.
# Converted VTSI.csv to parquet.
# Converted VTVT.csv to parquet.
# Converted VUZI.csv to parquet.
# Converted VVI.csv to parquet.
# Converted VVNT.csv to parquet.
# Converted VVPR.csv to parquet.
# Converted VVR.csv to parquet.
# Converted VVUS.csv to parquet.
# Converted VVV.csv to parquet.
# Converted VXRT.csv to parquet.
# Converted VXX.csv to parquet.
# Converted VXZ.csv to parquet.
# Converted VYGR.csv to parquet.
# Converted VZ.csv to parquet.
# Converted W.csv to parquet.
# Converted WAB.csv to parquet.
# Converted WABC.csv to parquet.
# Converted WAFD.csv to parquet.
# Converted WAFU.csv to parquet.
# Converted WAL.csv to parquet.
# Converted WALA.csv to parquet.
# Converted WASH.csv to parquet.
# Converted WAT.csv to parquet.
# Converted WATT.csv to parquet.
# Converted WB.csv to parquet.
# Converted WBA.csv to parquet.
# Converted WBAI.csv to parquet.
# Converted WBC.csv to parquet.
# Converted WBK.csv to parquet.
# Converted WBS.csv to parquet.
# Converted WBT.csv to parquet.
# Converted WCC.csv to parquet.
# Converted WCN.csv to parquet.
# Converted WD.csv to parquet.
# Converted WDAY.csv to parquet.
# Converted WDC.csv to parquet.
# Converted WDFC.csv to parquet.
# Converted WDR.csv to parquet.
# Converted WEA.csv to parquet.
# Converted WEBK.csv to parquet.
# Converted WEC.csv to parquet.
# Converted WEI.csv to parquet.
# Converted WELL.csv to parquet.
# Converted WEN.csv to parquet.
# Converted WERN.csv to parquet.
# Converted WES.csv to parquet.
# Converted WETF.csv to parquet.
# Converted WEX.csv to parquet.
# Converted WEYS.csv to parquet.
# Converted WF.csv to parquet.
# Converted WFC.csv to parquet.
# Converted WGO.csv to parquet.
# Converted WH.csv to parquet.
# Converted WHD.csv to parquet.
# Converted WHF.csv to parquet.
# Converted WHFBZ.csv to parquet.
# Converted WHG.csv to parquet.
# Converted WHLM.csv to parquet.
# Converted WHLR.csv to parquet.
# Converted WHLRD.csv to parquet.
# Converted WHLRP.csv to parquet.
# Converted WHR.csv to parquet.
# Converted WIA.csv to parquet.
# Converted WIFI.csv to parquet.
# Converted WIL.csv to parquet.
# Converted WILC.csv to parquet.
# Converted WINA.csv to parquet.
# Converted WING.csv to parquet.
# Converted WINS.csv to parquet.
# Converted WIRE.csv to parquet.
# Converted WISA.csv to parquet.
# Converted WIT.csv to parquet.
# Converted WIW.csv to parquet.
# Converted WIX.csv to parquet.
# Converted WK.csv to parquet.
# Converted WKEY.csv to parquet.
# Converted WKHS.csv to parquet.
# Converted WLDN.csv to parquet.
# Converted WLFC.csv to parquet.
# Converted WLK.csv to parquet.
# Converted WLKP.csv to parquet.
# Converted WLL.csv to parquet.
# Converted WLTW.csv to parquet.
# Converted WM.csv to parquet.
# Converted WMB.csv to parquet.
# Converted WMC.csv to parquet.
# Converted WMGI.csv to parquet.
# Converted WMK.csv to parquet.
# Converted WMS.csv to parquet.
# Converted WMT.csv to parquet.
# Converted WNC.csv to parquet.
# Converted WNEB.csv to parquet.
# Converted WNS.csv to parquet.
# Converted WOR.csv to parquet.
# Converted WORK.csv to parquet.
# Converted WORX.csv to parquet.
# Converted WOW.csv to parquet.
# Converted WPC.csv to parquet.
# Converted WPG.csv to parquet.
# Converted WPM.csv to parquet.
# Converted WPP.csv to parquet.
# Converted WPRT.csv to parquet.
# Converted WPX.csv to parquet.
# Converted WRB.csv to parquet.
# Converted WRE.csv to parquet.
# Converted WRI.csv to parquet.
# Converted WRK.csv to parquet.
# Converted WRLD.csv to parquet.
# Converted WRLS.csv to parquet.
# Converted WRLSU.csv to parquet.
# Converted WRN.csv to parquet.
# Converted WRTC.csv to parquet.
# Converted WSBC.csv to parquet.
# Converted WSBF.csv to parquet.
# Converted WSC.csv to parquet.
# Converted WSFS.csv to parquet.
# Converted WSG.csv to parquet.
# Converted WSM.csv to parquet.
# Converted WSO.csv to parquet.
# Converted WSR.csv to parquet.
# Converted WST.csv to parquet.
# Converted WSTG.csv to parquet.
# Converted WSTL.csv to parquet.
# Converted WTBA.csv to parquet.
# Converted WTER.csv to parquet.
# Converted WTFC.csv to parquet.
# Converted WTFCM.csv to parquet.
# Converted WTI.csv to parquet.
# Converted WTIU.csv to parquet.
# Converted WTM.csv to parquet.
# Converted WTRE.csv to parquet.
# Converted WTREP.csv to parquet.
# Converted WTRG.csv to parquet.
# Converted WTRH.csv to parquet.
# Converted WTRU.csv to parquet.
# Converted WTS.csv to parquet.
# Converted WTT.csv to parquet.
# Converted WTTR.csv to parquet.
# Converted WU.csv to parquet.
# Converted WUBA.csv to parquet.
# Converted WVE.csv to parquet.
# Converted WVFC.csv to parquet.
# Converted WVVI.csv to parquet.
# Converted WVVIP.csv to parquet.
# Converted WW.csv to parquet.
# Converted WWD.csv to parquet.
# Converted WWE.csv to parquet.
# Converted WWR.csv to parquet.
# Converted WWW.csv to parquet.
# Converted WY.csv to parquet.
# Converted WYND.csv to parquet.
# Converted WYNN.csv to parquet.
# Converted WYY.csv to parquet.
# Converted X.csv to parquet.
# Converted XAIR.csv to parquet.
# Converted XAN.csv to parquet.
# Converted XBIO.csv to parquet.
# Converted XBIOW.csv to parquet.
# Converted XBIT.csv to parquet.
# Converted XCUR.csv to parquet.
# Converted XEC.csv to parquet.
# Converted XEL.csv to parquet.
# Converted XELA.csv to parquet.
# Converted XELB.csv to parquet.
# Converted XENE.csv to parquet.
# Converted XENT.csv to parquet.
# Converted XERS.csv to parquet.
# Converted XFLT.csv to parquet.
# Converted XFOR.csv to parquet.
# Converted XGN.csv to parquet.
# Converted XHR.csv to parquet.
# Converted XIN.csv to parquet.
# Converted XLNX.csv to parquet.
# Converted XLRN.csv to parquet.
# Converted XNCR.csv to parquet.
# Converted XNET.csv to parquet.
# Converted XOG.csv to parquet.
# Converted XOM.csv to parquet.
# Converted XOMA.csv to parquet.
# Converted XONE.csv to parquet.
# Converted XP.csv to parquet.
# Converted XPEL.csv to parquet.
# Converted XPER.csv to parquet.
# Converted XPL.csv to parquet.
# Converted XPO.csv to parquet.
# Converted XRAY.csv to parquet.
# Converted XRF.csv to parquet.
# Converted XRX.csv to parquet.
# Converted XSPA.csv to parquet.
# Converted XTLB.csv to parquet.
# Converted XTNT.csv to parquet.
# Converted XVZ.csv to parquet.
# Converted XXII.csv to parquet.
# Converted XYF.csv to parquet.
# Converted XYL.csv to parquet.
# Converted Y.csv to parquet.
# Converted YCBD.csv to parquet.
# Converted YELP.csv to parquet.
# Converted YETI.csv to parquet.
# Converted YEXT.csv to parquet.
# Converted YGRN.csv to parquet.
# Converted YGYI.csv to parquet.
# Converted YGYIP.csv to parquet.
# Converted YI.csv to parquet.
# Converted YIN.csv to parquet.
# Converted YJ.csv to parquet.
# Converted YMAB.csv to parquet.
# Converted YNDX.csv to parquet.
# Converted YORW.csv to parquet.
# Converted YPF.csv to parquet.
# Converted YRCW.csv to parquet.
# Converted YRD.csv to parquet.
# Converted YTEN.csv to parquet.
# Converted YTRA.csv to parquet.
# Converted YUM.csv to parquet.
# Converted YUMA.csv to parquet.
# Converted YUMC.csv to parquet.
# Converted YVR.csv to parquet.
# Converted YY.csv to parquet.
# Converted Z.csv to parquet.
# Converted ZAGG.csv to parquet.
# Converted ZBH.csv to parquet.
# Converted ZBRA.csv to parquet.
# Converted ZCMD.csv to parquet.
# Converted ZDGE.csv to parquet.
# Converted ZEAL.csv to parquet.
# Converted ZEN.csv to parquet.
# Converted ZEUS.csv to parquet.
# Converted ZFGN.csv to parquet.
# Converted ZG.csv to parquet.
# Converted ZGNX.csv to parquet.
# Converted ZGYHU.csv to parquet.
# Converted ZION.csv to parquet.
# Converted ZIONL.csv to parquet.
# Converted ZIONN.csv to parquet.
# Converted ZIONO.csv to parquet.
# Converted ZIONP.csv to parquet.
# Converted ZIONW.csv to parquet.
# Converted ZIOP.csv to parquet.
# Converted ZIV.csv to parquet.
# Converted ZIXI.csv to parquet.
# Converted ZKIN.csv to parquet.
# Converted ZLAB.csv to parquet.
# Converted ZM.csv to parquet.
# Converted ZN.csv to parquet.
# Converted ZNGA.csv to parquet.
# Converted ZNH.csv to parquet.
# Converted ZOM.csv to parquet.
# Converted ZS.csv to parquet.
# Converted ZSAN.csv to parquet.
# Converted ZTO.csv to parquet.
# Converted ZTR.csv to parquet.
# Converted ZTS.csv to parquet.
# Converted ZUMZ.csv to parquet.
# Converted ZUO.csv to parquet.
# Converted ZVO.csv to parquet.
# Converted ZYME.csv to parquet.
# Converted ZYNE.csv to parquet.
# Converted ZYXI.csv to parquet.

# %%
import os
import pandas as pd

# Define the folders to process
csv_folders = [
    './05_src/data/prices_csv/etfs',
    './05_src/data/prices_csv/stocks'
]
parquet_folder = './05_src/data/prices/'

os.makedirs(parquet_folder, exist_ok=True)

for csv_folder in csv_folders:
    for csv_file in os.listdir(csv_folder):
        if csv_file.endswith('.csv'):
            csv_path = os.path.join(csv_folder, csv_file)
            df = pd.read_csv(csv_path)
            parquet_path = os.path.join(parquet_folder, csv_file.replace('.csv', '.parquet'))
            df.to_parquet(parquet_path)
            print(f"Converted {csv_file} to parquet.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 14
#      11 os.makedirs(parquet_folder, exist_ok=True)
#      13 for csv_folder in csv_folders:
# ---> 14     for csv_file in os.listdir(csv_folder):
#      15         if csv_file.endswith('.csv'):
#      16             csv_path = os.path.join(csv_folder, csv_file)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './05_src/data/prices_csv/etfs'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 10
#       6 parquet_folder = './05_src/data/prices'
#       8 os.makedirs(parquet_folder, exist_ok=True)
# ---> 10 for csv_file in os.listdir(csv_folder):
#      11     if csv_file.endswith('.csv'):
#      12         df = pd.read_csv(os.path.join(csv_folder, csv_file))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './05_src/data/prices_csv/etfs'

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to load the historical price data for stocks and ETFs, we could use:

# %% [markdown]
# Verify the structure of the `stock_prices` data:

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Download all prices.

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.
